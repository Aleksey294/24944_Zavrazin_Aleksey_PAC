# %%
import cv2
import os
import numpy as np

images_path = "nails_segmentation/images"
masks_path = "nails_segmentation/labels"

# %%
# task_1
image_files = sorted(os.listdir(images_path))
mask_files = sorted(os.listdir(masks_path))

pairs = []
for img_file in image_files:
    name_file = os.path.splitext(img_file)[0] + os.path.splitext(img_file)[1]

    if name_file in mask_files:
        pairs.append((os.path.join(images_path, img_file), os.path.join(masks_path, name_file)))

pairs
# Out:
# [('nails_segmentation/images\\09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg',
#   'nails_segmentation/labels\\09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg'),
#  ('nails_segmentation/images\\1eecab90-1a92-43a7-b952-0204384e1fae.jpg',
#   'nails_segmentation/labels\\1eecab90-1a92-43a7-b952-0204384e1fae.jpg'),
#  ('nails_segmentation/images\\2C29D473-CCB4-458C-926B-99D0042161E6.jpg',
#   'nails_segmentation/labels\\2C29D473-CCB4-458C-926B-99D0042161E6.jpg'),
#  ('nails_segmentation/images\\2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg',
#   'nails_segmentation/labels\\2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg'),
#  ('nails_segmentation/images\\34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg',
#   'nails_segmentation/labels\\34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg'),
#  ('nails_segmentation/images\\3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg',
#   'nails_segmentation/labels\\3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg'),
#  ('nails_segmentation/images\\41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg',
# ...

# %%
# task_2
i = 0

while True:
    img_path, mask_path = pairs[i]
    
    image = cv2.imread(img_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    
    mask_bgr = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    combined = np.hstack([image, mask_bgr])
    cv2.imshow("result", combined)
    
    key = cv2.waitKey(0) & 0xFF
    if key == 27:
        break
    elif key == ord('d'):
        i = (i + 1) % len(pairs)
    elif key == ord('a'):
        i = (i - 1) % len(pairs)

cv2.destroyAllWindows()

# %%
# task_3
i = 0
while True:
    img_path, mask_path = pairs[i]
    image = cv2.imread(img_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

    mask_bgr = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    combined = np.hstack([mask_bgr, image])

    cv2.imshow("result", combined)

    key = cv2.waitKey(0) & 0xFF
    if key == 27:
        break
    elif key == ord('d'):
        i = (i + 1) % len(pairs)
    elif key == ord('a'):
        i = (i - 1) % len(pairs)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 13
#      10 cv2.drawContours(image, contours, -1, (0, 255, 0), 2)
#      12 mask_bgr = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
# ---> 13 combined = np.hstack([mask, image])
#      15 cv2.imshow("result", combined)
#      17 key = cv2.waitKey(0) & 0xFF
#
# File c:\anac\Lib\site-packages\numpy\core\shape_base.py:359, in hstack(tup, dtype, casting)
#     357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
# --> 359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
# task_4
video = cv2.VideoCapture("videoplayback.mp4")

while True:
    _, frame = video.read()
    
    cv2.imshow('video', cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) )
    
    if cv2.waitKey(5) & 0xFF == 27:
        break

cv2.destroyAllWindows()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 27
#      25 mask = cv2.cvtColor(thresh, cv2.COLOR_GRAY2BGR)
#      26 result = np.zeros_like(frame)
# ---> 27 result[mask > 0] = [0, 0, 255]
#      28 result[mask == 0] = [0, 255, 0]
#      29 text = "Красный свет"
#
# ValueError: NumPy boolean array indexing assignment cannot assign 3 input values to the 0 output values where the mask is true
